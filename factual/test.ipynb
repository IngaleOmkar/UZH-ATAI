# %%
import requests
from difflib import SequenceMatcher
from typing import Optional, List, Dict, Tuple
import time
from urllib.parse import quote
import spacy
from spellchecker import SpellChecker
import rdflib
import re

# %%
class WikidataFinder:
    """
    A class to convert natural language strings to Wikidata URIs using fuzzy matching.
    """
    
    BASE_URL = "https://www.wikidata.org/w/api.php"
    WIKIDATA_URI_PREFIX = "http://www.wikidata.org/entity/"


    def extract_wikidata_id(self, uri: str) -> str:
        """
        Extract Wikidata ID (Q or P number) from a URI or direct ID string.
        
        Args:
            uri (str): Wikidata URI or ID (e.g., 'http://www.wikidata.org/entity/Q42', 
                    'http://www.wikidata.org/prop/direct/P495', 'Q42', or 'P495')
        
        Returns:
            str: The extracted Wikidata ID
            
        Raises:
            ValueError: If the URI doesn't contain a valid Wikidata ID
        """
        # Check if it's already just a Q/P number
        if re.match(r'^[QP]\d+$', uri):
            return uri
        
        # Extract from URI
        match = re.search(r'[QP]\d+', uri)
        if match:
            return match.group(0)
        
        raise ValueError(f"Invalid Wikidata identifier: {uri}")
    
    def get_wikidata_label(self, uri: str) -> str:
        """
        Convert a Wikidata URI to human readable text by querying the Wikidata API.
        Works for both entities (Q) and properties (P).
        
        Args:
            uri (str): Wikidata URI or ID (e.g., 'http://www.wikidata.org/entity/Q42', 
                    'http://www.wikidata.org/prop/direct/P495', 'Q42', or 'P495')
            
        Returns:
            str: Human readable label for the entity or property
            
        Raises:
            ValueError: If the URI is invalid
            RequestException: If the API request fails
        """
        # Extract the string from rdflib.term.URIRef
        uri = str(uri)
        try:
            entity_id = self.extract_wikidata_id(uri)
        except ValueError as e:
            return str(e)
        
        # Determine if it's a property or entity
        is_property = entity_id.startswith('P')
        
        # Construct the API URL
        api_url = 'https://www.wikidata.org/w/api.php'
        
        if is_property:
            # For properties, we need to use the wbgetentities API with different parameters
            params = {
                'action': 'wbgetentities',
                'ids': entity_id,
                'format': 'json',
                'props': 'labels|datatype',  # Include datatype for properties
                'languages': 'en'
            }
        else:
            # For regular entities
            params = {
                'action': 'wbgetentities',
                'ids': entity_id,
                'format': 'json',
                'props': 'labels',
                'languages': 'en'
            }
        
        try:
            response = requests.get(api_url, params=params)
            response.raise_for_status()
            data = response.json()
            
            # Check if entity/property exists
            if 'entities' not in data or entity_id not in data['entities']:
                return f"ID {entity_id} not found"
                
            # Get English label if available
            entity = data['entities'][entity_id]
            label = None
            
            if 'labels' in entity and 'en' in entity['labels']:
                label = entity['labels']['en']['value']
                
                # For properties, append the datatype if available
                if is_property and 'datatype' in entity:
                    label = f"{label} ({entity['datatype']})"
                    
                return label
            else:
                return f"No English label found for {entity_id}"
                
        except requests.exceptions.RequestException as e:
            raise requests.exceptions.RequestException(f"Failed to fetch data: {str(e)}")
    
    def __init__(self, language: str = "en", max_results: int = 5, similarity_threshold: float = 0.6):
        """
        Initialize the WikidataFinder.
        
        Args:
            language: Language code for search results (default: "en")
            max_results: Maximum number of search results to consider (default: 5)
            similarity_threshold: Minimum similarity score to consider a match (default: 0.6)
        """
        self.language = language
        self.max_results = max_results
        self.similarity_threshold = similarity_threshold
        
    def search_wikidata(self, query: str) -> List[Dict]:
        """
        Search Wikidata API for entities matching the query.
        """
        params = {
            "action": "wbsearchentities",
            "format": "json",
            "language": self.language,
            "search": query,
            "limit": self.max_results,
        }
        
        try:
            response = requests.get(self.BASE_URL, params=params)
            response.raise_for_status()
            data = response.json()
            return data.get("search", [])
        except requests.exceptions.RequestException as e:
            print(f"Error searching Wikidata: {e}")
            return []
            
    def calculate_similarity(self, query: str, target: str) -> float:
        """
        Calculate string similarity between query and target using SequenceMatcher.
        """
        return SequenceMatcher(None, query.lower(), target.lower()).ratio()
        
    def get_best_match(self, query: str, search_results: List[Dict]) -> Optional[Tuple[str, float]]:
        """
        Find the best matching entity from search results based on similarity score.
        """
        best_match = None
        highest_score = 0
        
        for result in search_results:
            # Check similarity with label and description
            label_score = self.calculate_similarity(query, result.get("label", ""))
            desc_score = self.calculate_similarity(query, result.get("description", "")) * 0.5
            
            # Combined score with more weight on label match
            combined_score = max(label_score, desc_score)
            
            if combined_score > highest_score and combined_score >= self.similarity_threshold:
                highest_score = combined_score
                best_match = (result.get("id"), combined_score)
                
        return best_match
        
    def get_wikidata_uri(self, query: str) -> Optional[Dict]:
        """
        Convert a natural language string to a Wikidata URI.
        
        Args:
            query: Natural language string to search for
            
        Returns:
            Dictionary containing:
                - uri: Wikidata URI if found
                - confidence: Similarity score
                - label: Entity label
                - description: Entity description
            Returns None if no match is found
        """
        if not query.strip():
            return None
            
        # Rate limiting
        time.sleep(0.1)
        
        # Search Wikidata
        results = self.search_wikidata(query)
        
        if not results:
            return None
            
        # Find best match
        best_match = self.get_best_match(query, results)
        
        if not best_match:
            return None
            
        entity_id, confidence = best_match
        
        # Get the matching result details
        match_details = next((r for r in results if r["id"] == entity_id), None)
        
        return {
            "uri": f"{self.WIKIDATA_URI_PREFIX}{entity_id}",
            "confidence": round(confidence, 3),
            "label": match_details.get("label"),
            "description": match_details.get("description")
        }

# %%
import pickle

# Load the pickle file
with open('triples.pkl', 'rb') as file:
    data = pickle.load(file)

# %%
subject_predicate_to_object, predicate_object_to_subject, subject_object_to_predicate = data

# %%
# Example usage
subject_object_to_predicate
# Out:
# {(rdflib.term.URIRef('http://www.wikidata.org/entity/Q22674394'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q11424')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q516483'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q16')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P27')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q4196443'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q580231')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3335591'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q376749')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P19')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1420651'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q20644797')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1981')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1310131'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q18683957')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P58'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P57')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q17028740'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q973472')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q15452558'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q30')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P27')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1384699'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q253192')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q12343523'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q152629'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1860')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P407')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1209853'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1889355')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q20'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q38')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P530')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2293972'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q24869')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1552')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q4188333'),
#   rdflib.term.Literal('tt1664664', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q6316687'),
#   rdflib.term.Literal('2007-03-30', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#date'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P577')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q97958848'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q33999')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P106')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q26720312'),
#   rdflib.term.Literal('Geneviève Robert', lang='en')): [rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q27964337'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q319221')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q457820'),
#   rdflib.term.Literal('commune in Pas-de-Calais, France', lang='en')): [rdflib.term.URIRef('http://schema.org/description')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1108528'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1425151')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1142862'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q348445')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1478915'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q310617')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P361')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q22663902'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q12439')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P19')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q8240308'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3576983')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P344')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1163628'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q169889')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P272')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q21208008'),
#   rdflib.term.Literal('American actress', lang='en')): [rdflib.term.URIRef('http://schema.org/description')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q15408539'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q150')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1412')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q8836325'),
#   rdflib.term.Literal('American baseball player', lang='en')): [rdflib.term.URIRef('http://schema.org/description')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1077206'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3246821')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q126652'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q90')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P840'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P915')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q270878'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q21528200'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q230004')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2627558'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q142')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P495')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q7614194'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q723764'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2775969')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q531043'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1373348')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2554')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3598715'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q4165246')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P5021')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q41755711'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q11424')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3769065'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q652')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1412')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q472600'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3168898')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2829927'),
#   rdflib.term.Literal('Alain Janey', lang='en')): [rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q130769'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q830079')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q967335'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q930862')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q21527930'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q80948336')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P750')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2625088'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q219402')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q6139160'),
#   rdflib.term.Literal('nm4574630', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1138965'),
#   rdflib.term.Literal('character in the Resident Evil franchise', lang='en')): [rdflib.term.URIRef('http://schema.org/description')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q6537230'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2757345'),
#   rdflib.term.Literal('Spanish actress', lang='en')): [rdflib.term.URIRef('http://schema.org/description')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1658594'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q228852')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1741078'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1496419')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2554')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1783832'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q53050')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P58'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P57')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q648312'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q125354')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2061614'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5240309')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P6942'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P57')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1813350'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q875920')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P750'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P272')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q174'),
#   rdflib.term.Literal('largest city in Brazil', lang='en')): [rdflib.term.URIRef('http://schema.org/description')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2708940'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q65')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P840'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P915')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2700181'),
#   rdflib.term.Literal('Gul Panag', lang='en')): [rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q512376'),
#   rdflib.term.Literal('https://commons.wikimedia.org/wiki/File:Suzy_Nakamura_on_Sidewalks.jpg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P18')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q649165'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q101797')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2578200'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q65')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P915')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q61654745'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q7945367')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P58')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q948793'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q34804')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P19')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q96469'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1022')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P20')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q206740'),
#   rdflib.term.Literal('tt0080489', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1255003'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q723685')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P437')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3156821'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q4922844'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2449490')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P915')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q4658861'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q93204')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q807842'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1860')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P364')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1164940'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1860')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P364')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q910226'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q205868')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q5463351'),
#   rdflib.term.Literal('Flying Bark Productions', lang='en')): [rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q28212248'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q723685')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P437')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q11947'),
#   rdflib.term.Literal('1925-01-01', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#date'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P577')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2865'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q61980648')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q16731129'),
#   rdflib.term.Literal('Canadian film director', lang='en')): [rdflib.term.URIRef('http://schema.org/description')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q498489'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q884')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P27')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q4838247'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q84')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P159')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q10263747'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1748')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P840')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1199203'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q441705')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2891067'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q29')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P495')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1339491'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q145')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P27')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q361238'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q18432')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P19')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q664182'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q492214')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1441')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q17089799'),
#   rdflib.term.Literal('tt2570738', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q15487381'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q24826')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P19')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q890656'),
#   rdflib.term.Literal('Pokémon Heroes', lang='en')): [rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q558481'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q209459')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3133377'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q30')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P495')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q5307500'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1152815')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1272933'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q162753')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q5066084'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q381477')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P57'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P58'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q5222996'),
#   rdflib.term.Literal('nm0412999', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q549249'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1146335')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q273168'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q37320')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P19')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q55578373'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q72')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P19')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q57982258'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q365230')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P344')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q961893'),
#   rdflib.term.Literal('American lyricist and librettist', lang='en')): [rdflib.term.URIRef('http://schema.org/description')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2915471'),
#   rdflib.term.Literal('American actress', lang='en')): [rdflib.term.URIRef('http://schema.org/description')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q5557205'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q23830577')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2747')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q841274'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q16679862')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P156')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q15207314'),
#   rdflib.term.Literal('tt1631707', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2690472'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2839609')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P57')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q44402493'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1638629')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1441')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q472147'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1440194'),
#   rdflib.term.Literal('romantic', lang='en')): [rdflib.term.URIRef('http://ddis.ch/atai/tag')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q810441'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q465449')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P272'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P750')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q159'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q822')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P530')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q10787597'),
#   rdflib.term.Literal('Vietnamese actor', lang='en')): [rdflib.term.URIRef('http://schema.org/description')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1686618'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q217352')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P144')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1127709'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1860')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P364')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1107998'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q23301856')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2629')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2634881'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q12756132')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3523363'),
#   rdflib.term.Literal('1999-01-01', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#date'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P577')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3640890'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q30')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P27')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q23017675'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q23760776'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q668')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P27')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q685785'),
#   rdflib.term.Literal('alternate_history', lang='en')): [rdflib.term.URIRef('http://ddis.ch/atai/tag')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1849238'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q723685')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P437')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q15710886'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3730899')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P27')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q5045127'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1860')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1412')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q184768'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q318292')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1522552'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q38')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P27')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q7620503'),
#   rdflib.term.Literal('Asterix', lang='en')): [rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2564319'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q157443')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1740809'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q471839')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3236871'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q723685')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P437')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3927578'),
#   rdflib.term.Literal('2006 film', lang='en')): [rdflib.term.URIRef('http://schema.org/description')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q111625'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q365')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P937')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2089221'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q6066032')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3968304'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q649542'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q23830577')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2747')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1057015'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q6073889')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q83484'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1860')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1412')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q25078'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q245068')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P106')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q98454793'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q33231')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P106')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q62513'),
#   rdflib.term.Literal('The Kautokeino Rebellion', lang='en')): [rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q81274532'),
#   rdflib.term.Literal('Marthe Bernard', lang='en')): [rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q22000321'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q74434535')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P7573')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2033820'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q117238'),
#   rdflib.term.Literal('nm0776973', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q16251439'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q16633368')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3204546'),
#   rdflib.term.Literal('2012-01-01', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#date'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P577')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q25401545'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q105641628')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P5021')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q5364798'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3313322')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P26')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q44059'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5119')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q11296603'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q106991881')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P551'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P108')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q7497228'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q6555926'),
#   rdflib.term.Literal('co0082557', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q596260'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1860')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P364')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1754478'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q52162262')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q7678658'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q17')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P27'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P19')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q22252048'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q11424')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q83389'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3640')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P159')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q456375'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q33999')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P106')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1144426'),
#   rdflib.term.Literal('Japanese voice actress', lang='en')): [rdflib.term.URIRef('http://schema.org/description')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q7701944'),
#   rdflib.term.Literal('nm1134166', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3311075'),
#   rdflib.term.Literal('Michel Vigné', lang='en')): [rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q169150'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q38337')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1889'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P22')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q179215'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1860')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P364')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q104682331'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1860')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P364')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3559142'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q959790')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q966420'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q30')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P27')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q643847'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q56887761')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P5970')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1140578'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q79202')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P750'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P272')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q69303989'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q37491218')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q77819608'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q30')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P27')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q17497016'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q150')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P103'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1412')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1744805'),
#   rdflib.term.Literal('nm0335779', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1211174'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q993643')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P344')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q15879670'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q213326')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1441')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q4138948'),
#   rdflib.term.Literal('Gears', lang='en')): [rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q62066193'),
#   rdflib.term.Literal('nm4074404', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q102448'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q24869')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q646077'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q959790')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q406'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3551')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P190')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q6696881'),
#   rdflib.term.Literal('https://commons.wikimedia.org/wiki/File:Luciano_Szafir.jpg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P18')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q43707937'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q65')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P19')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2615318'),
#   rdflib.term.Literal('Manuel Broekman', lang='en')): [rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q11540347'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q326792'),
#   rdflib.term.Literal('Czech dubbing actor, actor and university educator', lang='en')): [rdflib.term.URIRef('http://schema.org/description')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q170583'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q145')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P495')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1115248'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5516982')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P750')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q16641860'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q22006653')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P462')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3415074'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q452788')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q96642'),
#   rdflib.term.Literal('https://commons.wikimedia.org/wiki/File:Hans-Christian-Schmid.jpg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P18')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q931009'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q628637')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q180395'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q188473')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q76435'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1794')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P19')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2445193'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q36704')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P27')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q7457447'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q22006653')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P462')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q12130601'),
#   rdflib.term.Literal('2017 film by Terrence Malick', lang='en')): [rdflib.term.URIRef('http://schema.org/description')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3770744'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q172579')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P27')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q138005'),
#   rdflib.term.Literal('American actor, producer, and director', lang='en')): [rdflib.term.URIRef('http://schema.org/description')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q18128126'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q281249')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P57'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P58')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1343328'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q645928')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1210771'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3132886')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q6411532'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1486')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P19'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P20')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1552595'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q706364')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P106')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1063525'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q41417')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q20492737'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q33999')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P106')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q28473085'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q7411')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P103'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1412')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1663443'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q95906112'),
#   rdflib.term.Literal('Martin Nahálka', lang='en')): [rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q19608827'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q514736')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q4913767'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q130232')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3876322'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q220')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P19')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1561383'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q403')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P27')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3926951'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1528043')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P58'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P57')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1800380'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q35610')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1877')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q7832799'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q22006653')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P462')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q832515'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q311319')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q14945820'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q130232')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q731901'),
#   rdflib.term.Literal('Croatian actor', lang='en')): [rdflib.term.URIRef('http://schema.org/description')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q114471'),
#   rdflib.term.Literal('https://commons.wikimedia.org/wiki/File:Special_Edition_NYC_2014_-_Huntress_(14244669400).jpg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P18')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q9087879'),
#   rdflib.term.Literal('Spanish actor', lang='en')): [rdflib.term.URIRef('http://schema.org/description')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q64681734'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q145')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P27')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1909936'),
#   rdflib.term.Literal('German actor', lang='en')): [rdflib.term.URIRef('http://schema.org/description')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q63009'),
#   rdflib.term.Literal('The Prince of Tides', lang='en')): [rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q7626673'),
#   rdflib.term.Literal('Canadian actor', lang='en')): [rdflib.term.URIRef('http://schema.org/description')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2939224'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q33999')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P106')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q5259997'),
#   rdflib.term.Literal('nm1235154', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q36998754'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q723685')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P437')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1113987'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q712180')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q48672477'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q4550895')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2629')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1022513'),
#   rdflib.term.Literal('The Sound of Music', lang='en')): [rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q6137906'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q33999')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P106')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q162667'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q30')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P27')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q8070192'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q33999')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P106')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q7367039'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q45')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P17')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q96409568'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q723685')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P437')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q151945'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5582745')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P272')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2939833'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5146')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1412')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1214303'),
# ...
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1165071'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q270668')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P674')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q932792'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5083')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P19')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q242623'),
#   rdflib.term.Literal('nm0812133', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q15844918'),
#   rdflib.term.Literal('nm0337013', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1820801'),
#   rdflib.term.Literal('nm0540804', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q500460'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q30')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P495')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q492485'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q9186')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P364')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q12325623'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q35')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P27')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q399823'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q976575')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q23001300'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1868645'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1860')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1412')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q48744320'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q723685')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P437')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q4102124'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q33999')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P106')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q26726740'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q17485699')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1441')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q6767740'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q33999')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P106')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q69684738'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2807')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P20'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P19')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1632935'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2190976')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P58')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q651296'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q296822')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q644150'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q830079')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q12757218'),
#   rdflib.term.Literal('Serbian and Montenegro actor,TV presenter', lang='en')): [rdflib.term.URIRef('http://schema.org/description')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q96608250'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q725686')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q67106850'),
#   rdflib.term.Literal('nm6082237', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1116991'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q242889')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q735383'),
#   rdflib.term.Literal('1981 film directed by Jean-Jacques Beineix', lang='en')): [rdflib.term.URIRef('http://schema.org/description')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q17517020'),
#   rdflib.term.Literal('nm0124112', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q28355528'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q649')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P20'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P19')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1055796'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q130232')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q13794921'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q900426')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2608065'),
#   rdflib.term.Literal('clever', lang='en')): [rdflib.term.URIRef('http://ddis.ch/atai/tag')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q322451'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q12047513')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P279')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1198900'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q860626')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3392082'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q57619'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q150')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1412')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q585554'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q79637782')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3738071'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3836714'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3481483')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q11685219'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1860')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1412')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q106816260'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q20974000')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q21755531'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q27253939')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P3306')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q52152001'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q14370012'),
#   rdflib.term.Literal('Deliver Us from Evil', lang='en')): [rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1745428'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q59782081')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P674')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q605857'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q150')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1412'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P103')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q59423'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q142')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P495'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P840')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q872394'),
#   rdflib.term.Literal('Árpád Csernák', lang='en')): [rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q106316'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1999640')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1496725'),
#   rdflib.term.Literal('In Enemy Hands', lang='en')): [rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q178348'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q18154821')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q893419'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q959790')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q5935633'),
#   rdflib.term.Literal('Cuban filmmaker', lang='en')): [rdflib.term.URIRef('http://schema.org/description')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q20165868'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q9056')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1412')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q223367'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1860')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P364')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q471580'),
#   rdflib.term.Literal('Bekim Fehmiu', lang='en')): [rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q31'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q43702')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q7721023'),
#   rdflib.term.Literal('tt1890559', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q287274'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q7343547')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P58')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q48322275'),
#   rdflib.term.Literal('Museum', lang='en')): [rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q20165881'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q751921')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1441')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q210873'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q30')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P495')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q148429'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q532192')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q447584'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q30')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P27')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3053255'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1421655')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P57')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q441272'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q64692313'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2901988')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P4969')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q578809'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q30')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P495')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3490932'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1195998'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q838368')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P462')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q173804'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q134077')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q984077'),
#   rdflib.term.Literal('https://commons.wikimedia.org/wiki/File:NickSwardsonCCJul2011.jpg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P18')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q117315'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q41375')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1333403'),
#   rdflib.term.Literal('https://commons.wikimedia.org/wiki/File:Fachadas_de_La_Granja.jpg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P18')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q65029924'),
#   rdflib.term.Literal('nm3117666', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2141715'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q30')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P495')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q477570'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q22006653')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P462')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q811999'),
#   rdflib.term.Literal('Bavaria - Traumreise durch Bayern', lang='en')): [rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q12047645'),
#   rdflib.term.Literal('Pusté kostely', lang='en')): [rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q5505303'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q157443')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3564265'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q33999')): [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P106')],
#  ...}

# %%
finder = WikidataFinder()

result = finder.get_wikidata_uri("language")
if result:
    print(f"URI: {result['uri']}")
else:
    print(f"\nNo match found for")
# Out:
# URI: http://www.wikidata.org/entity/Q34770

# %%
from transformers import pipeline

# Load the pre-trained NER pipeline
ner_pipeline = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english", aggregation_strategy="simple")
# Out:
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
def extract_ner(sentence):
    # Perform Named Entity Recognition
    ner_results = ner_pipeline(sentence)

    # Extract and print the entity names
    entities = [entity['word'] for entity in ner_results if entity['entity_group'] in ['PER', 'LOC', 'ORG', 'MISC']]
    return entities

extract_ner("Steven Spielberg is a famous director who was born in Cincinnati, Ohio.")
# Out:
# ['Steven Spielberg', 'Cincinnati', 'Ohio']

# %%
common_movie_related_entities = ['director', 'actor', 'actress', 'actors', 'actresses', 'cast', 'revenue', 'released'
                                 'screenwriter', 'producer', 'production', 'genre', 'plot', 'rating', 'awards', 'budget', 'box office'
                                 'film', 'movie', 'citizenship', 'birth', 'birthplace', 'death', 'deathplace', 'national']

# %%
def query_dictionary(uri_1, uri_2):
    uri_1 = rdflib.term.URIRef(uri_1)
    uri_2 = rdflib.term.URIRef(uri_2)
    print(uri_1, uri_2)
    
    if((uri_1, uri_2) in subject_predicate_to_object):
        return finder.get_wikidata_label(subject_predicate_to_object[(uri_1, uri_2)])
    elif((uri_1, uri_2) in subject_object_to_predicate):
        return finder.get_wikidata_label(subject_object_to_predicate[(uri_1, uri_2)])
    elif((uri_1, uri_2) in predicate_object_to_subject):
        return finder.get_wikidata_label(predicate_object_to_subject[(uri_1, uri_2)])
    else:
        uri_1, uri_2 = uri_2, uri_1
        if((uri_1, uri_2) in subject_predicate_to_object):
            return finder.get_wikidata_label(subject_predicate_to_object[(uri_1, uri_2)])
        elif((uri_1, uri_2) in subject_object_to_predicate):
            return finder.get_wikidata_label(subject_object_to_predicate[(uri_1, uri_2)])
        elif((uri_1, uri_2) in predicate_object_to_subject):
            return finder.get_wikidata_label(predicate_object_to_subject[(uri_1, uri_2)])
        else:
            return "No relationship found between the two entities."

def answer_query(query):
    # Extract named entities from the query
    entities = extract_ner(query)
    if not entities:
        return "No entities found in the query."
    if(len(entities) == 1):
        # check if any word in query is in common_movie_related_entities
        for word in query.split():
            # Remove all punctuation and special characters
            word = ''.join(e for e in word if e.isalnum())
            if word in common_movie_related_entities:
                uri_1 = finder.get_wikidata_uri(entities[0])['uri']
                uri_2 = finder.get_wikidata_uri(word)
                if uri_2:
                    uri_2 = uri_2['uri']
                    ans = query_dictionary(uri_1, uri_2)
                return ans

    if len(entities) == 2:
        uri_1 = finder.get_wikidata_uri(entities[0])['uri']
        uri_2 = finder.get_wikidata_uri(entities[1])['uri']
        return query_dictionary(uri_1, uri_2)
        
query = "Steve Van Wormer instance of?"
print("I believe that the answer to that question is: ", answer_query(query))
# Out:
# I believe that the answer to that question is:  None

# %%
subject_object_to_predicate[(rdflib.term.URIRef('http://www.wikidata.org/entity/Q7614194'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q5'))]
# Out:
# [rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')]

# %%
subject_predicate_to_object
# Out:
# {(rdflib.term.URIRef('http://www.wikidata.org/entity/Q22674394'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q11424')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q516483'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P27')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q16')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q4196443'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q580231')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3335591'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P19')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q376749')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1420651'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1981')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q20644797')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1310131'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P58')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q18683957'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q6405871')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q17028740'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q973472'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q257271'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q472084'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q220308'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q306403'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2827706'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q112536'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q336400'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q313107'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q515095'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1358888'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3132470'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q7436480')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q15452558'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P27')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q30')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1384699'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q253192'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q235622'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q4831765'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q261981'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q379171'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q444410'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q10841812'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q311165'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5478514'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q952724')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q12343523'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q152629'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P407')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q1860')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1209853'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q1889355'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1744'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q783369'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2865227'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1262126'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q827443'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q730270'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q323503'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q42930'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q95030'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q4017804'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q679987'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q310295'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1859510'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1375484'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q932204'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q452400'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2939081'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q267097'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2967592'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q233365'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2081108'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q23072512'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q329784'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1399617'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q313671'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q544465'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q658690'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q232541'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q350255'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1389759'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3047186'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1384373'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3157232'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1066934'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q449602'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q346833'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q95043'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q579100'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q708153'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q41163'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q447892')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q20'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P530')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q38'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q30'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q142'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q801'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q974'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q16'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q96'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1049'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q889'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q212'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q851'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q837'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q189'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q218'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q145'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q739'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q711'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q34'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q33946'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q458'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q408'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q865'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q28'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q224'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q159'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q15180'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q229'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q148'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q41'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q843'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q183'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q423'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q35'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1246'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q403'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q833'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q33'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q664')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2293972'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1552')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q24869'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q219557')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q4188333'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')): [rdflib.term.Literal('tt1664664', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q6316687'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P577')): [rdflib.term.Literal('2007-03-30', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#date'))],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q97958848'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P106')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q33999')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q26720312'),
#   rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')): [rdflib.term.Literal('Geneviève Robert', lang='en')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q27964337'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q319221'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q25110269'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q157443'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q157394'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q28968258'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1361932')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q457820'),
#   rdflib.term.URIRef('http://schema.org/description')): [rdflib.term.Literal('commune in Pas-de-Calais, France', lang='en')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1108528'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q1425151'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q917808'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q240201'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q338757')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1142862'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q348445'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q944819'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2341317'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1233502'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q7297265'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5416186'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2080947'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q39972'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q530957'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2474995'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q7387159'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q593286'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q173585'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q737183'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q467570'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q495321'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q910625'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5258412'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q4913513'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q18227'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q7507770'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q532715'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q513739'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q174843'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1677148'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q523687')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1478915'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P361')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q310617')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q22663902'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P19')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q12439')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q8240308'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P344')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q3576983')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1163628'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P272')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q169889'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q7679179')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q21208008'),
#   rdflib.term.URIRef('http://schema.org/description')): [rdflib.term.Literal('American actress', lang='en')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q15408539'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1412')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q150')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q8836325'),
#   rdflib.term.URIRef('http://schema.org/description')): [rdflib.term.Literal('American baseball player', lang='en')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1077206'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q3246821'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q15632617'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q15773347')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q126652'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P840')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q90')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q270878'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q21528200'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q230004'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q310930'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q105682'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q218800'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5929749'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2845494'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q7704911'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3218669'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q18395801'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q6113745'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q18684166'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q591515'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2692341')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2627558'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P495')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q142')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q7614194'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q723764'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q2775969'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1037127')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q531043'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2554')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q1373348')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3598715'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P5021')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q4165246')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q41755711'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q11424')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3769065'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1412')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q652')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q472600'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q3168898'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1342843'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q180224'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q707500'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q234890'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3066913'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q319527'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5626030'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q355835'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q6292322'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q437415'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q60304'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q391297'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3086542'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q204394'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1974920'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1396779'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q461945'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q382396'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q239341'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3082304'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q19544020'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q203215'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q292760'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3218807')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2829927'),
#   rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')): [rdflib.term.Literal('Alain Janey', lang='en')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q130769'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q830079'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q504298'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q103360'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q102427'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q103916')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q967335'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q930862'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1031692'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q201810'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2050238'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1341507'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3440076'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3483072'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2905002'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3189294'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2910406'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2602323'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3471319'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q328511'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3499140'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3192383'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3189442'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1450857'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2964183'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3418669'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3460880'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3286441'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q308840'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3362788'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q465157'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3196011'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q171557'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q262822'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q551873'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3018752'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3158341'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q728158'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2869522'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q437254'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3386401'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3155677'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q259940'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3397928'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q314972')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q21527930'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P750')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q80948336'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q907311'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q434841')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2625088'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q219402'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q937117'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q232397'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2832463'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q378978'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q180342'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q534006'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2356564'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q7659422'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q234544'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q4767298'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q4954196'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q16729296'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q559074'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q508404'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q182763'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q6483409'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q266804'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3482458'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1043065'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q14535')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q6139160'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')): [rdflib.term.Literal('nm4574630', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1138965'),
#   rdflib.term.URIRef('http://schema.org/description')): [rdflib.term.Literal('character in the Resident Evil franchise', lang='en')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q6537230'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2757345'),
#   rdflib.term.URIRef('http://schema.org/description')): [rdflib.term.Literal('Spanish actress', lang='en')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1658594'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q228852'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1378118'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q170530'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q231911'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q193555'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q491775'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q73035'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q44077'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q23517'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q926912'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q4260536'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q16297')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1741078'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2554')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q1496419')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1783832'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P58')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q53050'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q268443'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3751607'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3726620')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q648312'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q125354'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q103784'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1058672'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1139248'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q164119'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q523142'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q92633'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q80046'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q255060'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q169963'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q186757'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1457631'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3952813'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3776572'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q125904'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q38875')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2061614'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P6942')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q5240309'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q66755260'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q66756249'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2829322'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q66755699'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q29363531'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q66756374'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3180035'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q7026284'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3154582'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q66755852'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q55950320'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q66756220'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q66756253'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q4336463'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q318953'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q66756190'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q57459214'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q66755575'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q66755574'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q66756278')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1813350'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P750')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q875920')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q174'),
#   rdflib.term.URIRef('http://schema.org/description')): [rdflib.term.Literal('largest city in Brazil', lang='en')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2708940'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P840')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q65')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2700181'),
#   rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')): [rdflib.term.Literal('Gul Panag', lang='en')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q512376'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P18')): [rdflib.term.Literal('https://commons.wikimedia.org/wiki/File:Suzy_Nakamura_on_Sidewalks.jpg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q649165'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q101797'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q6323445'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1139190'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q35332'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q528723'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q44380'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q180272'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q159778'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q106175'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q259913'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5004260'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q42930'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q172261'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3103867'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q463402'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q184903'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q44221'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1120700'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2572165'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q229254'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q238924'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q230378'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q103939'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1545414')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2578200'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P915')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q65')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q61654745'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P58')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q7945367'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1400238'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q455862'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q18358288'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5053366')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q948793'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P19')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q34804')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q96469'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P20')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q1022')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q206740'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')): [rdflib.term.Literal('tt0080489', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1255003'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P437')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q723685')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3156821'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q4922844'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P915')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q2449490'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q16552')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q4658861'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q93204')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q807842'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P364')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q1860')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1164940'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P364')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q1860')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q910226'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q205868'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q462314'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q956867'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3376671'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1187605'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q34851'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3294532'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q151973'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q232845'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q4020156'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q322399'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3200960'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q230563'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q347711'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q944296'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q190924'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q434267')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q5463351'),
#   rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')): [rdflib.term.Literal('Flying Bark Productions', lang='en')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q28212248'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P437')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q723685')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q11947'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P577')): [rdflib.term.Literal('1925-01-01', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#date'))],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2865'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q61980648'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q134626'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1549591'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1180262'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q42744322'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q253030')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q16731129'),
#   rdflib.term.URIRef('http://schema.org/description')): [rdflib.term.Literal('Canadian film director', lang='en')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q498489'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P27')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q884')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q4838247'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P159')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q84')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q10263747'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P840')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q1748')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1199203'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q441705'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2221232'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2125195'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q580032'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1700513'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q763065'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3830310'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3218065'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3430707'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1285368'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3414025'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q470998')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2891067'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P495')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q29'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q414')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1339491'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P27')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q145')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q361238'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P19')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q18432')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q664182'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1441')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q492214'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q108745'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2365168')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q17089799'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')): [rdflib.term.Literal('tt2570738', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q15487381'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P19')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q24826')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q890656'),
#   rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')): [rdflib.term.Literal('Pokémon Heroes', lang='en')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q558481'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q209459')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3133377'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P495')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q30')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q5307500'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q1152815'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5173585'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q382078'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q449822'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q350595'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1174314'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q6409182')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1272933'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q162753'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q697188'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3164879'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1097113'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3063686'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q658664'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q17636476'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q15069872'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q116314'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q106482'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q10311712'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2131240'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q743958'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3308841'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3164973'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q444570'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3367708'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3241961'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1324016'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3341887'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3573655'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q978266'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2965972'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1685182'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3293483')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q5066084'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P57')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q381477')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q5222996'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')): [rdflib.term.Literal('nm0412999', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q549249'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q1146335'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q157443'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q130232')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q273168'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P19')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q37320')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q55578373'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P19')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q72')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q57982258'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P344')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q365230')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q961893'),
#   rdflib.term.URIRef('http://schema.org/description')): [rdflib.term.Literal('American lyricist and librettist', lang='en')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2915471'),
#   rdflib.term.URIRef('http://schema.org/description')): [rdflib.term.Literal('American actress', lang='en')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q5557205'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2747')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q23830577')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q841274'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P156')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q16679862')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q15207314'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')): [rdflib.term.Literal('tt1631707', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2690472'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P57')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q2839609')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q44402493'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1441')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q1638629'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q166354')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q472147'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1440194'),
#   rdflib.term.URIRef('http://ddis.ch/atai/tag')): [rdflib.term.Literal('romantic', lang='en')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q810441'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P272')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q465449')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q159'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P530')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q822'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q236'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q912'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q869'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1033'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q233'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q45'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q262'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1030'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q221'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q115'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q837'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q334'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q265'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q916'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q29'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q40'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q189'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1027'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q739'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q863'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q754'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q711'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q414'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q298'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q31'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q34'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q227'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q219060'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q796'),
# ...
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P3306')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q27253939'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q27253957')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q52152001'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q14370012'),
#   rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')): [rdflib.term.Literal('Deliver Us from Evil', lang='en')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1745428'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P674')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q59782081')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q605857'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1412')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q150'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1860')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q59423'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P495')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q142')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q872394'),
#   rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')): [rdflib.term.Literal('Árpád Csernák', lang='en')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q106316'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q1999640'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q4720733'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q242763'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2031670'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1659349'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q714976'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q484615'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q317228'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q472282'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q273497'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q83338'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q355133'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3760593'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2012197'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q486103'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2252829'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q193160'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q532922'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3161881'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2982614'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2683767'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1336571')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1496725'),
#   rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')): [rdflib.term.Literal('In Enemy Hands', lang='en')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q178348'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q18154821'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q18154829'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q734036')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q893419'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q959790'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q200092'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q853630')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q5935633'),
#   rdflib.term.URIRef('http://schema.org/description')): [rdflib.term.Literal('Cuban filmmaker', lang='en')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q20165868'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1412')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q9056')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q223367'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P364')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q1860')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q471580'),
#   rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')): [rdflib.term.Literal('Bekim Fehmiu', lang='en')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q31'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q43702'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3624078'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1250464'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q6256'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q20181813'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q185441')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q7721023'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')): [rdflib.term.Literal('tt1890559', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q287274'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P58')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q7343547')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q48322275'),
#   rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')): [rdflib.term.Literal('Museum', lang='en')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q20165881'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1441')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q751921')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q210873'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P495')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q30')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q148429'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q532192'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q217573'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q318158'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q403902'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q387072'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q453774'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1312914'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q509117'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q257317'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1117390'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q37459'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q275254'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q229230'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q40791')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q447584'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P27')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q30')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3053255'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P57')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q1421655')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q441272'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q64692313'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P4969')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q2901988')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q578809'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P495')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q30')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3490932'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1195998'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P462')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q838368')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q173804'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q134077'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q760856'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q28493'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q76361'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q69705'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1001175'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q76887'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q312712'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q18175708'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1414870'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q721323'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q630962'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q381414'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q234195'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q234128'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1120300'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q665941'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q75866'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q535507'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q356397'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q235721'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q796061'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q67881'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q109855'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3998508'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q453876'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q862358'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q435312'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q105825'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1736665'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q573109'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q233801')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q984077'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P18')): [rdflib.term.Literal('https://commons.wikimedia.org/wiki/File:NickSwardsonCCJul2011.jpg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q117315'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q41375'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q4649799'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q4649795'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q4649797'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q787145'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q4649800'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q6978539'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1967719'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q8038461'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q103360'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q4649792'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q103618'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q41417'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q4649801'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q102427'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q131520'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q6978541'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q822907'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q139184'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q849124'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q739633'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q787098'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q499789'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q4649817'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q277536'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1315008'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1268927'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q787131'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q4649826'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q586356'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q4649821'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1720784'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1422140'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3404521'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q3600406'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q2295011'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q463085'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q4649807'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q687123'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q281939'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q900414'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q1011509'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q4649808'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q106301'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q4745055'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q5280675'),
#   rdflib.term.URIRef('http://www.wikidata.org/entity/Q4649818')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1333403'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P18')): [rdflib.term.Literal('https://commons.wikimedia.org/wiki/File:Fachadas_de_La_Granja.jpg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q65029924'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345')): [rdflib.term.Literal('nm3117666', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2141715'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P495')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q30')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q477570'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P462')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q22006653')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q811999'),
#   rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')): [rdflib.term.Literal('Bavaria - Traumreise durch Bayern', lang='en')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q12047645'),
#   rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')): [rdflib.term.Literal('Pusté kostely', lang='en')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q5505303'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q157443')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3564265'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P106')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q33999')],
#  (rdflib.term.URIRef('http://www.wikidata.org/entity/Q5352401'),
#   rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31')): [rdflib.term.URIRef('http://www.wikidata.org/entity/Q11424')],
#  ...}
